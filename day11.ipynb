# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import boxcox

# %%
data=np.random.exponential(scale=2, size=1000)
df=pd.DataFrame({"Salary":data})

# %%
df.head()
# Out:
#      Salary
# 0  0.126260
# 1  1.879840
# 2  0.559226
# 3  0.040104
# 4  6.832381

# %%
plt.figure(figsize=(6,4))
sns.histplot(df.Salary)
plt.show()

# %%
df.Salary.skew()
# Out:
# np.float64(1.4930903663063668)

# %%
df["updated_Salary"], lambda_val=boxcox(df.Salary)

# %%
df.head()
# Out:
#      Salary  updated_Salary
# 0  0.126260       -1.558253
# 1  1.879840        0.692307
# 2  0.559226       -0.535089
# 3  0.040104       -2.095739
# 4  6.832381        2.568095

# %%
lambda_val
# Out:
# np.float64(0.2884929727704339)

# %%
plt.figure(figsize=(6,4))
sns.histplot(df.updated_Salary)
plt.show()

# %%
data=np.random.exponential(scale=2, size=1000)
data=10-data
df=pd.DataFrame({"Salary2":data})

# %%
df.head()
# Out:
#     Salary2
# 0  9.231025
# 1  9.258392
# 2  7.636235
# 3  7.694861
# 4  9.676501

# %%
plt.figure(figsize=(6,4))
sns.histplot(df.Salary2)
plt.show()

# %%
df.Salary2.skew()
# Out:
# np.float64(-2.3761328939647073)

# %%
df["reflex_Salary"] = (df.Salary2.max() - df.Salary2) + 1

# %%
df.head()
# Out:
#     Salary2  reflex_Salary
# 0  9.231025       1.768780
# 1  9.258392       1.741413
# 2  7.636235       3.363571
# 3  7.694861       3.304944
# 4  9.676501       1.323305

# %%
df["transformed_salary"]=np.log(df.reflex_Salary)+1

# %%
df.head()
# Out:
#     Salary2  reflex_Salary  transformed_salary
# 0  9.231025       1.768780            1.570290
# 1  9.258392       1.741413            1.554697
# 2  7.636235       3.363571            2.213003
# 3  7.694861       3.304944            2.195420
# 4  9.676501       1.323305            1.280132

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\USER\Downloads\test2.csv")

# %%
df
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
df.shape
# Out:
# (6, 5)

# %%
df["Age"]=df["Age"].fillna(df["Age"].median())

# %%
df
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David  29.0         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
df
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David  29.0         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
encodeer=LabelEncoder()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\USER\Downloads\data_visualization.csv")

# %%
data
# Out:
#     Unnamed: 0  Student_ID     Name  Gender Department  Age  Math_Score  \
# 0            0           1    Aarav    Male         CS   21          78
# 1            1           2     Diya  Female         IT   22          85
# 2            2           3    Rohan    Male         CS   20          90
# 3            3           4    Sneha  Female        ECE   21          67
# 4            4           5    Arjun    Male         IT   23          88
# 5            5           6    Meera  Female        ECE   22          76
# 6            6           7    Kiran    Male         CS   21          92
# 7            7           8   Ananya  Female         IT   20          81
# 8            8           9    Rahul    Male        ECE   22          74
# 9            9          10     Isha  Female         CS   23          89
# 10          10          11   Vikram    Male         IT   21          84
# 11          11          12    Pooja  Female         CS   20          91
# ...

# %%
plt.figure()

# %%
sns.pairplot(data)

# %%
plt.plot(data.Math_Score, color="red")
plt.grid()
plt.show()

# %%
plt.plot(data.Math_Score, color="red")
plt.grid()
plt.title("Line chart")
plt.show()

# %%
img=plt.imread(r"C:\Users\USER\Pictures\yogi.1.jpg")
plt.imshow(img)

# %%
plt.bar(range(len(data.Math_Score)), data.Math_Score, color="red")
plt.grid()
plt.title("Bar Chart")
plt.show()

# %%
plt.hist(data.Math_Score, bins=10, color="red")
plt.grid()
plt.title("Histogram")
plt.show()

# %%
plt.scatter(range(len(data.Math_Score)), data.Math_Score, color="red")
plt.grid()
plt.title("Scatter Plot")
plt.show()

# %%
score_counts = data.Math_Score.value_counts()
plt.pie(score_counts, labels=score_counts.index)
plt.title("Pie Chart")
plt.show()

# %%
plt.scatter(range(len(data.Math_Score)), data.Math_Score)
plt.title("Dot Chart")
plt.grid()
plt.show()
